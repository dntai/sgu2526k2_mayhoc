# %%
# %run ex1_calc
# Out:
# Calculator Basic
# Moi ban nhap so a:  10
# Moi ban nhap so b:  20
# c = 10 + 20 = 30

# %%
# !jupyter nbconvert --to html my_lesson1.ipynb
# Out:
# [NbConvertApp] Converting notebook my_lesson1.ipynb to html
# [NbConvertApp] Writing 268884 bytes to my_lesson1.html
